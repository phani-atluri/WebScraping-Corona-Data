# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers=[]
t_row=[]

page =  requests.get('https://www.mohfw.gov.in/')
bss = BeautifulSoup(page.content,'html.parser')
head=bss.find('thead')
table=bss.find('tbody')


def Corona():
    for row in head.findAll('tr'):
        for results in row.text.split('\n'):
            if results=='':
                continue
            else:
                headers.append(results)
    t_row=[rows for rows in table.findAll('tr')]
    state=[{headers[index]:cell.text for index,cell in enumerate(row.find_all("td")) }for row in t_row]
    state.pop()
    state.pop()
    return state
Corona()
# Out:
# [{'S. No.': '1',
#   'Name of State / UT': 'Andhra Pradesh',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '427',
#   'Cured/Discharged/Migrated': '11',
#   'Death': '7'},
#  {'S. No.': '2',
#   'Name of State / UT': 'Andaman and Nicobar Islands',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '11',
#   'Cured/Discharged/Migrated': '10',
#   'Death': '0'},
#  {'S. No.': '3',
#   'Name of State / UT': 'Arunachal Pradesh',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '1',
#   'Cured/Discharged/Migrated': '0',
#   'Death': '0'},
#  {'S. No.': '4',
#   'Name of State / UT': 'Assam',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '29',
#   'Cured/Discharged/Migrated': '0',
#   'Death': '1'},
#  {'S. No.': '5',
#   'Name of State / UT': 'Bihar',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '64',
#   'Cured/Discharged/Migrated': '19',
#   'Death': '1'},
#  {'S. No.': '6',
#   'Name of State / UT': 'Chandigarh',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '21',
#   'Cured/Discharged/Migrated': '7',
#   'Death': '0'},
#  {'S. No.': '7',
#   'Name of State / UT': 'Chhattisgarh',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '31',
#   'Cured/Discharged/Migrated': '10',
#   'Death': '0'},
#  {'S. No.': '8',
#   'Name of State / UT': 'Delhi',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '1154',
#   'Cured/Discharged/Migrated': '27',
#   'Death': '24'},
#  {'S. No.': '9',
#   'Name of State / UT': 'Goa',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '7',
#   'Cured/Discharged/Migrated': '5',
#   'Death': '0'},
#  {'S. No.': '10',
#   'Name of State / UT': 'Gujarat',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '516',
#   'Cured/Discharged/Migrated': '44',
#   'Death': '25'},
#  {'S. No.': '11',
#   'Name of State / UT': 'Haryana',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '185',
#   'Cured/Discharged/Migrated': '29',
#   'Death': '3'},
#  {'S. No.': '12',
#   'Name of State / UT': 'Himachal Pradesh',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '32',
#   'Cured/Discharged/Migrated': '13',
#   'Death': '1'},
#  {'S. No.': '13',
#   'Name of State / UT': 'Jammu and Kashmir',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '245',
#   'Cured/Discharged/Migrated': '6',
#   'Death': '4'},
#  {'S. No.': '14',
#   'Name of State / UT': 'Jharkhand',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '19',
#   'Cured/Discharged/Migrated': '0',
#   'Death': '2'},
#  {'S. No.': '15',
#   'Name of State / UT': 'Karnataka',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '232',
#   'Cured/Discharged/Migrated': '57',
#   'Death': '6'},
#  {'S. No.': '16',
#   'Name of State / UT': 'Kerala',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '376',
#   'Cured/Discharged/Migrated': '179',
#   'Death': '2'},
#  {'S. No.': '17',
#   'Name of State / UT': 'Ladakh',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '15',
#   'Cured/Discharged/Migrated': '10',
#   'Death': '0'},
#  {'S. No.': '18',
#   'Name of State / UT': 'Madhya Pradesh',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '564',
#   'Cured/Discharged/Migrated': '0',
#   'Death': '36'},
#  {'S. No.': '19',
#   'Name of State / UT': 'Maharashtra',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '1985',
#   'Cured/Discharged/Migrated': '217',
#   'Death': '149'},
#  {'S. No.': '20',
#   'Name of State / UT': 'Manipur',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '2',
#   'Cured/Discharged/Migrated': '1',
#   'Death': '0'},
#  {'S. No.': '21',
#   'Name of State / UT': 'Mizoram',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '1',
#   'Cured/Discharged/Migrated': '0',
#   'Death': '0'},
#  {'S. No.': '22',
#   'Name of State / UT': 'Odisha',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '54',
#   'Cured/Discharged/Migrated': '12',
#   'Death': '1'},
#  {'S. No.': '23',
#   'Name of State / UT': 'Puducherry',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '7',
#   'Cured/Discharged/Migrated': '1',
#   'Death': '0'},
#  {'S. No.': '24',
#   'Name of State / UT': 'Punjab',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '151',
#   'Cured/Discharged/Migrated': '5',
#   'Death': '11'},
#  {'S. No.': '25',
#   'Name of State / UT': 'Rajasthan',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '804',
#   'Cured/Discharged/Migrated': '21',
#   'Death': '3'},
#  {'S. No.': '26',
#   'Name of State / UT': 'Tamil Nadu',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '1043',
#   'Cured/Discharged/Migrated': '50',
#   'Death': '11'},
#  {'S. No.': '27',
#   'Name of State / UT': 'Telengana',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '504',
#   'Cured/Discharged/Migrated': '43',
#   'Death': '9'},
#  {'S. No.': '28',
#   'Name of State / UT': 'Tripura',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '2',
#   'Cured/Discharged/Migrated': '0',
#   'Death': '0'},
#  {'S. No.': '29',
#   'Name of State / UT': 'Uttarakhand',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '35',
#   'Cured/Discharged/Migrated': '5',
#   'Death': '0'},
#  {'S. No.': '30',
#   'Name of State / UT': 'Uttar Pradesh',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '483',
#   'Cured/Discharged/Migrated': '46',
#   'Death': '5'},
#  {'S. No.': '31',
#   'Name of State / UT': 'West Bengal',
#   'Total Confirmed cases (Including 72 foreign Nationals) ': '152',
#   'Cured/Discharged/Migrated': '29',
#   'Death': '7'}]

# %%
Corona()
# Out:
# [{'S. No.': '1', 'Name of State / UT': 'Andhra Pradesh', 'Total Confirmed cases (Including 72 foreign Nationals) ': '427', 'Cured/Discharged/Migrated': '11', 'Death': '7'}, {'S. No.': '2', 'Name of State / UT': 'Andaman and Nicobar Islands', 'Total Confirmed cases (Including 72 foreign Nationals) ': '11', 'Cured/Discharged/Migrated': '10', 'Death': '0'}, {'S. No.': '3', 'Name of State / UT': 'Arunachal Pradesh', 'Total Confirmed cases (Including 72 foreign Nationals) ': '1', 'Cured/Discharged/Migrated': '0', 'Death': '0'}, {'S. No.': '4', 'Name of State / UT': 'Assam', 'Total Confirmed cases (Including 72 foreign Nationals) ': '29', 'Cured/Discharged/Migrated': '0', 'Death': '1'}, {'S. No.': '5', 'Name of State / UT': 'Bihar', 'Total Confirmed cases (Including 72 foreign Nationals) ': '64', 'Cured/Discharged/Migrated': '19', 'Death': '1'}, {'S. No.': '6', 'Name of State / UT': 'Chandigarh', 'Total Confirmed cases (Including 72 foreign Nationals) ': '21', 'Cured/Discharged/Migrated': '7', 'Death': '0'}, {'S. No.': '7', 'Name of State / UT': 'Chhattisgarh', 'Total Confirmed cases (Including 72 foreign Nationals) ': '31', 'Cured/Discharged/Migrated': '10', 'Death': '0'}, {'S. No.': '8', 'Name of State / UT': 'Delhi', 'Total Confirmed cases (Including 72 foreign Nationals) ': '1154', 'Cured/Discharged/Migrated': '27', 'Death': '24'}, {'S. No.': '9', 'Name of State / UT': 'Goa', 'Total Confirmed cases (Including 72 foreign Nationals) ': '7', 'Cured/Discharged/Migrated': '5', 'Death': '0'}, {'S. No.': '10', 'Name of State / UT': 'Gujarat', 'Total Confirmed cases (Including 72 foreign Nationals) ': '516', 'Cured/Discharged/Migrated': '44', 'Death': '25'}, {'S. No.': '11', 'Name of State / UT': 'Haryana', 'Total Confirmed cases (Including 72 foreign Nationals) ': '185', 'Cured/Discharged/Migrated': '29', 'Death': '3'}, {'S. No.': '12', 'Name of State / UT': 'Himachal Pradesh', 'Total Confirmed cases (Including 72 foreign Nationals) ': '32', 'Cured/Discharged/Migrated': '13', 'Death': '1'}, {'S. No.': '13', 'Name of State / UT': 'Jammu and Kashmir', 'Total Confirmed cases (Including 72 foreign Nationals) ': '245', 'Cured/Discharged/Migrated': '6', 'Death': '4'}, {'S. No.': '14', 'Name of State / UT': 'Jharkhand', 'Total Confirmed cases (Including 72 foreign Nationals) ': '19', 'Cured/Discharged/Migrated': '0', 'Death': '2'}, {'S. No.': '15', 'Name of State / UT': 'Karnataka', 'Total Confirmed cases (Including 72 foreign Nationals) ': '232', 'Cured/Discharged/Migrated': '57', 'Death': '6'}, {'S. No.': '16', 'Name of State / UT': 'Kerala', 'Total Confirmed cases (Including 72 foreign Nationals) ': '376', 'Cured/Discharged/Migrated': '179', 'Death': '2'}, {'S. No.': '17', 'Name of State / UT': 'Ladakh', 'Total Confirmed cases (Including 72 foreign Nationals) ': '15', 'Cured/Discharged/Migrated': '10', 'Death': '0'}, {'S. No.': '18', 'Name of State / UT': 'Madhya Pradesh', 'Total Confirmed cases (Including 72 foreign Nationals) ': '564', 'Cured/Discharged/Migrated': '0', 'Death': '36'}, {'S. No.': '19', 'Name of State / UT': 'Maharashtra', 'Total Confirmed cases (Including 72 foreign Nationals) ': '1985', 'Cured/Discharged/Migrated': '217', 'Death': '149'}, {'S. No.': '20', 'Name of State / UT': 'Manipur', 'Total Confirmed cases (Including 72 foreign Nationals) ': '2', 'Cured/Discharged/Migrated': '1', 'Death': '0'}, {'S. No.': '21', 'Name of State / UT': 'Mizoram', 'Total Confirmed cases (Including 72 foreign Nationals) ': '1', 'Cured/Discharged/Migrated': '0', 'Death': '0'}, {'S. No.': '22', 'Name of State / UT': 'Odisha', 'Total Confirmed cases (Including 72 foreign Nationals) ': '54', 'Cured/Discharged/Migrated': '12', 'Death': '1'}, {'S. No.': '23', 'Name of State / UT': 'Puducherry', 'Total Confirmed cases (Including 72 foreign Nationals) ': '7', 'Cured/Discharged/Migrated': '1', 'Death': '0'}, {'S. No.': '24', 'Name of State / UT': 'Punjab', 'Total Confirmed cases (Including 72 foreign Nationals) ': '151', 'Cured/Discharged/Migrated ...

# %%
import pandas as pd
df=pd.DataFrame(Corona())
df
# Out:
#    S. No.           Name of State / UT  \
# 0       1               Andhra Pradesh
# 1       2  Andaman and Nicobar Islands
# 2       3            Arunachal Pradesh
# 3       4                        Assam
# 4       5                        Bihar
# 5       6                   Chandigarh
# 6       7                 Chhattisgarh
# 7       8                        Delhi
# 8       9                          Goa
# 9      10                      Gujarat
# 10     11                      Haryana
# 11     12             Himachal Pradesh
# 12     13            Jammu and Kashmir
# 13     14                    Jharkhand
# 14     15                    Karnataka
# 15     16                       Kerala
# 16     17                       Ladakh
# 17     18               Madhya Pradesh
# 18     19                  Maharashtra
# 19     20                      Manipur
# 20     21                      Mizoram
# 21     22                       Odisha
# 22     23                   Puducherry
# 23     24                       Punjab
# 24     25                    Rajasthan
# 25     26                   Tamil Nadu
# 26     27                    Telengana
# 27     28                      Tripura
# 28     29                  Uttarakhand
# 29     30                Uttar Pradesh
# 30     31                  West Bengal
#
#    Total Confirmed cases (Including 72 foreign Nationals)   \
# 0                                                 427
# 1                                                  11
# 2                                                   1
# 3                                                  29
# 4                                                  64
# 5                                                  21
# 6                                                  31
# 7                                                1154
# 8                                                   7
# 9                                                 516
# 10                                                185
# 11                                                 32
# 12                                                245
# 13                                                 19
# 14                                                232
# 15                                                376
# 16                                                 15
# 17                                                564
# 18                                               1985
# 19                                                  2
# 20                                                  1
# 21                                                 54
# 22                                                  7
# 23                                                151
# 24                                                804
# 25                                               1043
# 26                                                504
# 27                                                  2
# 28                                                 35
# 29                                                483
# 30                                                152
#
#    Cured/Discharged/Migrated Death
# 0                         11     7
# 1                         10     0
# 2                          0     0
# 3                          0     1
# 4                         19     1
# 5                          7     0
# 6                         10     0
# 7                         27    24
# 8                          5     0
# 9                         44    25
# 10                        29     3
# 11                        13     1
# 12                         6     4
# 13                         0     2
# 14                        57     6
# 15                       179     2
# 16                        10     0
# 17                         0    36
# 18                       217   149
# 19                         1     0
# 20                         0     0
# 21                        12     1
# 22                         1     0
# 23                         5    11
# 24                        21     3
# 25                        50    11
# 26                        43     9
# 27                         0     0
# 28                         5     0
# 29                        46     5
# 30                        29     7

# %%
import matplotlib.pyplot as plt
states = df['Name of State / UT'].head()
confirmed_cases=df['Death'].head()
plt.bar(states,confirmed_cases);
